# %% [markdown]
# # 信号与系统 HW1 代码实践

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.axisartist as axisartist

# %% [markdown]
# ## 第一部分 绘制函数图像

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False    #用来正常显示负号

#1.1
x=np.arange(-2.5,2.5,0.01)
y=np.cos(2*np.pi*x)+1
plt.grid(True)
plt.plot(x, y, label='f(t)')
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(2.5, -0.05, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.1, 2.1, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.1.png")
plt.show()
# Out:
# D:\Software\Working\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Software\Working\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Software\Working\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 26102 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Software\Working\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 38388 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Software\Working\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False    #用来正常显示负号

#1.2
t=np.arange(-4,4,0.01)
#y=((1/3)*np.cos(np.pi*x)+1)*np.sin(8*np.pi*x)
f1=(1/3)*np.cos(np.pi*t)+1
f2=np.sin(8*np.pi*t)
f=f1*f2
plt.plot(t, f, label='f(t)')
plt.plot(t, f1, 'y',dashes=[6,2], linewidth=1, label='包络线')
plt.plot(t, -f1, 'y',dashes=[6,2], linewidth=1)
ax.text(4.5, -0.1, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.2, 1.5, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.2.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False    #用来正常显示负号

#1.3
t=np.arange(-6,6,0.001)
f1=np.sin(20*t)
f2=2*np.exp(-np.abs(t))
f=f1*f2
plt.plot(t, f, label='f(t)')
plt.plot(t, f2, 'y',dashes=[6,2], linewidth=1, label='包络线')
plt.plot(t, -f2, 'y',dashes=[6,2], linewidth=1)
ax.text(6.5, -0.1, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.2, 2.2, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.3.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False    #用来正常显示负号

#1.4
t=np.arange(-2.2,2.2,0.01)
f1=np.sin(2*np.pi*t)
f = [0 if (i<0) else 1 for i in f1]
plt.plot(t,f,label='f(t)')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(2.2, -0.04, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.1, 1.05, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.4.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False    #用来正常显示负号

#1.5
x=np.arange(-2,2,0.01)
u1 = [0 if (i<0) else 1 for i in x+1]
u2 = [0 if (i<0) else 1 for i in x-1]
y=np.exp(-0.5*x)*(u1)-np.exp(-0.5*x)*(u2)
x1=np.arange(-1.3,2,0.01)
y1=np.exp(-0.5*x1)
plt.plot(x,y,label='f(t)')
plt.plot(x1, y1, 'y',dashes=[6,2], linewidth=1, label='指数函数')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(2, -0.05, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.021, 2.02, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.5.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")

#1.6
x=np.arange(-15,15,1)
u = [0 if (i<0) else 1 for i in x]
v=[]
for i in x:
    if i<0:
        v.append(0)
    elif i==0:
        v.append(0.5)
    else :
        v.append(1)
y=(0.5)**(x)*u
x1=np.arange(-0.6,15,0.01)
y1=(0.5)**(x1)
plt.stem(x,y,linefmt=None,markerfmt='o',basefmt=' ',label='f[n]')
plt.plot(x1, y1, 'y',dashes=[6,2], linewidth=1, label='指数函数')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(14, -0.05, '时间(n)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.2, 1.56, '信号f[n]', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.6.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")

#1.7
x=np.arange(-15,15,1)
u = [0 if (i>0) else 1 for i in x]
v=[]
for i in x:
    if i>0:
        v.append(0)
    elif i==0:
        v.append(0.5)
    else :
        v.append(1)
y=np.exp(0.2*x)*u
x1=np.arange(-15,2,0.01)
y1=np.exp(0.2*x1)

plt.stem(x,y,linefmt=None,markerfmt='o',basefmt=' ',label='f[n]')
plt.plot(x1, y1, 'y',dashes=[6,2], linewidth=1, label='指数函数')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(14, -0.05, '时间(n)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.2, 1.57, '信号f[n]', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.7.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")

#1.8.1
x=np.arange(-10,10,0.01)
sinc=np.sin(x)/x
sinc3=np.sin(x/3)/(x/3)
sinc5=np.sin(x/5)/(x/5)
y=sinc*sinc3*sinc5
plt.plot(x,y,label='f(t)')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(10.1, -0.05, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.2, 1.05, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.8.1.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")

#1.8.2
x=np.arange(-4,5,1)
y=np.sin(np.pi*x*x/3)
x1=np.arange(-4.5,5,0.001)
y1=np.sin(np.pi*x1*x1/3)
plt.stem(x,y,linefmt=None,markerfmt='o',basefmt=' ',label='f[n]')
plt.plot(x1, y1, 'y',dashes=[6,2], linewidth=1, label='三角函数')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(5, -0.05, '时间(n)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.05, 1.1, '信号f[n]', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.8.2.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")

#1.8.3
x=np.arange(-1,1,0.0001)
u = [0 if (i<0) else 1 for i in x]
y=np.sin(2*np.pi/x)*u
plt.plot(x,y,label='f(t)')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(1, -0.05, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.05, 1.1, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.8.3.png")
plt.show()

# %%
#进行绘图调整
fig = plt.figure(figsize=(8, 8))
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
ax.axis[:].set_visible(False)
ax.axis["x"] = ax.new_floating_axis(0,0)
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"] = ax.new_floating_axis(1,0)
ax.axis["y"].set_axisline_style("-|>", size = 1.0)
ax.axis["x"].set_axis_direction("top")
ax.axis["y"].set_axis_direction("right")

#1.8.4
x=np.arange(-5,5,0.0001)
y = [1/(i-np.floor(i)) if (i-np.floor(i)) != 0 else 100 for i in x]
plt.xlim([-4,4]) #指X轴的显示范围
plt.ylim([0,10]) #指Y轴的显示范围
plt.plot(x,y,label='f(t)')
plt.grid(True)
plt.legend(loc='upper right')
plt.tight_layout()
ax.text(3.7, 0.3, '时间(t)', fontsize=10)#选择合适的位置放置x轴的标签
ax.text(0.05, 10.1, '信号f(t)', fontsize=10)#选择合适的位置放置y轴的标签
plt.savefig("D:\\Desktop\\信号与系统作业\\HW1\\1.8.4.png")
plt.show()

# %% [markdown]
# ## 第二部分 写出函数信号表达式
#
# 略

# %% [markdown]
# ## 第三部分 判断信号函数周期性

# %% [markdown]
# 3.4 判断$f(t)=[cos(3t)]^3$周期性

# %% [markdown]
# 解决这个问题，我们不妨把他的函数图像画出来，在绘画之前，我觉得周期大概是$\frac{2}{3}\pi$

# %%
#3.4
x=np.arange(-5,5,0.0001)
y = np.cos(3*x)**3
plt.plot(x,y,label='f(t)')
plt.grid(True)
plt.show()

# %% [markdown]
# 好的画了一下我发现确实是这样

# %% [markdown]
# 3.5 判断函数$sin(4t^3)$的周期性

# %%
#3.5
x=np.arange(-5,5,0.0001)
y = np.cos(4*(x**3))
plt.plot(x,y,label='f(t)')
plt.grid(True)
plt.show()

# %% [markdown]
# 3.6 判断函数$cos(\frac{\pi}{5}n^3)$的周期性

# %%
#3.6
x=np.arange(-15,15,1)
y = np.cos(0.2*np.pi*(x**3))
plt.plot(x,y,label='f(t)')
plt.grid(True)
plt.show()

# %%
#3.7.1
x=np.arange(-15,15,1)
y = np.cos(4/7*np.pi*x)+x
plt.plot(x,y,label='f(t)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 第四部分 冲击信号的抽样特性

# %% [markdown]
# ## 第五部分 信号的直流分量

# %% [markdown]
# ## 第六部分 实验

# %% [markdown]
# ### 6.1 DTMF音频中的电话号码

# %%
import sys,os,math,time
import matplotlib.pyplot as plt
from numpy import *
from scipy.io import wavfile

filename = 'D:/Desktop/HW1/PhoneSound.wav'
sample_rate,sig = wavfile.read(filename)
print(sample_rate)
print(sig.size)
print("sample_rate: {}\n".format(sample_rate), "shape(sig): {}\n".format(shape(sig)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-6fb27a435da2> in <module>
#       5
#       6 filename = 'D:/Desktop/HW1/PhoneSound.wav'
# ----> 7 sample_rate,sig = wavfile.read(filename)
#       8 print(sample_rate)
#       9 print(sig.size)
#
# D:\Software\Working\anaconda\lib\site-packages\scipy\io\wavfile.py in read(filename, mmap)
#     637         mmap = False
#     638     else:
# --> 639         fid = open(filename, 'rb')
#     640
#     641     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/Desktop/HW1/PhoneSound.wav'

# %%
plt.clf()
plt.figure(figsize=(10,6))
plt.plot(sig)
plt.xlabel("n")
plt.ylabel("value")
plt.grid(True)
plt.tight_layout()
plt.savefig('D:/Desktop/HW1/PhoneSound.jpg')
plt.show()

# %% [markdown]
# 这里学习一下scipy中的signal.spectrogram是什么东西：
#
# 首先看一下函数参数：
# scipy.signal.spectrogram(x, fs=1.0, window=(‘tukey’, 0.25), nperseg=None, noverlap=None, nfft=None, detrend=’constant’, return_onesided=True, scaling=’density’, axis=-1, mode=’psd’)
#
# Parameters:
# * x:输入的时间序列
# * fs:float型，采样频率，默认值为1.0
# * window:分窗大小，默认使用参数为0.25的Tukey window
# * nperseg:int型 窗口长度
# * noverlap:int型 段与段之间的重叠面积
# * nfft : int, optional，FFT的长度（那么FFT是什么？）
#
# 其他参数貌似没有用到咱可以先不理会。

# %%
from scipy import signal

startid=40000
endid=140000
f,t,Sxx = signal.spectrogram(sig[startid:endid],fs = sample_rate,nperseg =548, noverlap=0, nfft=8192)

plt.clf()
plt.figure(figsize=(10,7))
plt.pcolormesh(t, f[0:800], Sxx[:800][:], shading='gouraud')

plt.xlabel("Time(S)")
plt.ylabel("Frequency(Hz)")
plt.grid(True)
plt.tight_layout()

plt.savefig('D:/Desktop/HW1/out.jpg')
plt.show()

# %% [markdown]
# 还是没太弄明白，真是失败的一天
